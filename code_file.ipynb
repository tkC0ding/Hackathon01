# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# %%
df1 = pd.read_csv("Data/df1.csv")
df2 = pd.read_csv("Data/df2.csv")
df3 = pd.read_csv("Data/df3.csv")
df4 = pd.read_csv("Data/df4.csv")
df5 = pd.read_csv("Data/df5.csv")

# %%
df = pd.concat([df1, df2, df3, df4, df5], axis=0, ignore_index=True)

# %%
df.head()
# Out:
#    product_id       product_name          product_type  orders_monday  \
# 0           1  LG TV Bravia 22.1            Technology             10
# 1           2         WD-40 Glue  Convenience Products              5
# 2           3     Cotton Threads         Raw Materials              8
# 3           4         Smartphone            Technology             12
# 4           5       Steel Sheets         Raw Materials              7
#
#    orders_tuesday  orders_wednesday  orders_thursday  orders_friday   location
# 0             118                 9               11             10     Jaipur
# 1               6                 4                7              5  Ahmedabad
# 2               7                 6                9              8       Pune
# 3              10                11               13             12     Jaipur
# 4               5                 6                8              7       Pune

# %%
df['product_id'] = df.index.values

# %%
df
# Out:
#      product_id       product_name          product_type  orders_monday  \
# 0             0  LG TV Bravia 22.1            Technology             10
# 1             1         WD-40 Glue  Convenience Products              5
# 2             2     Cotton Threads         Raw Materials              8
# 3             3         Smartphone            Technology             12
# 4             4       Steel Sheets         Raw Materials              7
# ..          ...                ...                   ...            ...
# 145         145          Earphones            Technology            390
# 146         146           Speakers            Technology            410
# 147         147         Power Bank            Technology            430
# 148         148          USB Cable            Technology            450
# 149         149         Hard Drive            Technology            470
#
#      orders_tuesday  orders_wednesday  orders_thursday  orders_friday  \
# 0               118                 9               11             10
# 1                 6                 4                7              5
# 2                 7                 6                9              8
# 3                10                11               13             12
# 4                 5                 6                8              7
# ..              ...               ...              ...            ...
# 145             395               399              402            405
# 146             415               418              422            426
# 147             434               438              441            445
# 148             455               459              462            465
# 149             475               479              483            487
#
#       location
# 0       Jaipur
# 1    Ahmedabad
# 2         Pune
# 3       Jaipur
# 4         Pune
# ..         ...
# 145     Jaipur
# 146  Ahmedabad
# 147       Pune
# 148     Jaipur
# 149       Pune
#
# [150 rows x 9 columns]

# %%
df = df.sample(frac=1, ignore_index=True)

# %%
df.drop(columns='product_id', inplace=True)
df.head()
# Out:
#   product_name product_type  orders_monday  orders_tuesday  orders_wednesday  \
# 0       Tablet   Technology            190             195               199
# 1        Towel     Toiletry             80              81                82
# 2    Earphones   Technology            120             121               122
# 3   Power Bank   Technology            130             131               132
# 4         Soap     Toiletry             85              86                87
#
#    orders_thursday  orders_friday location
# 0              203            207     Pune
# 1               83             84   Jaipur
# 2              123            124   Jaipur
# 3              133            134     Pune
# 4               88             89     Pune

# %% [markdown]
# # Product list - based on index I have given numbers to each product

# %%
product_list = list(df['product_name'].unique())

# %% [markdown]
# # Type List - same method

# %%
type_list = list(df['product_type'].unique())

# %%
def name_replace(obj):
    return(product_list.index(obj))

# %%
df['product_name'] = df['product_name'].apply(name_replace)

# %%
def type_replace(obj):
    return(type_list.index(obj))

# %%
df['product_type'] = df['product_type'].apply(type_replace)

# %%
df.head()
# Out:
#    product_name  product_type  orders_monday  orders_tuesday  \
# 0             0             0            190             195
# 1             1             1             80              81
# 2             2             0            120             121
# 3             3             0            130             131
# 4             4             1             85              86
#
#    orders_wednesday  orders_thursday  orders_friday location
# 0               199              203            207     Pune
# 1                82               83             84   Jaipur
# 2               122              123            124   Jaipur
# 3               132              133            134     Pune
# 4                87               88             89     Pune

# %%
df.drop(columns='location', inplace=True)

# %%
df.head()
# Out:
#    product_name  product_type  orders_monday  orders_tuesday  \
# 0             0             0            190             195
# 1             1             1             80              81
# 2             2             0            120             121
# 3             3             0            130             131
# 4             4             1             85              86
#
#    orders_wednesday  orders_thursday  orders_friday
# 0               199              203            207
# 1                82               83             84
# 2               122              123            124
# 3               132              133            134
# 4                87               88             89

# %%
col_list = list(df.columns)[2:]

# %%
day_data = []
for i in col_list:
    day_data.append(df.loc[:, ['product_name', 'product_type', i]])

# %%
model_list = []
for i in range(5):
    model_list.append(LinearRegression())

# %%
train_list = []
test_list = []
for i in day_data:
    x = i.iloc[:, :-1]
    y = i.iloc[:, -1]
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)
    train_list.append((x_train, y_train))
    test_list.append((x_test, y_test))

# %%
pred_list = []
for i in range(5):
    model = model_list[i]
    x_train = np.array(train_list[i][0])
    y_train = np.array(train_list[i][1])
    x_test = np.array(test_list[i][0])
    y_test = np.array(test_list[i][1])

    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    pred_list.append((y_test, y_pred))

# %% [markdown]
# # Model List:
#
# ## Index value, day
#
# - 0, Monday
# - 1, Tuesday
# - 2, Wednesday
# - 3, Thursday
# - 4, Friday

# %%
model_list

# %% [markdown]
# ### idk how good the models will be cuz the data is dummy data and it is not much, but it should be fyn :)
